# %%
import os
import shutil
import stat
import seaborn as sns
import collections
import h5py
import numpy as np
import tensorflow as tf
import matplotlib.image as img
import random
import cv2
import PIL
import matplotlib.pyplot as plt
import matplotlib.image as img
from os import listdir
from os.path import isfile, join
from collections import defaultdict
from ipywidgets import interact, interactive, fixed
import ipywidgets as widgets
from sklearn.model_selection import train_test_split
from skimage.io import imread
from keras.utils.np_utils import to_categorical
from keras.applications.inception_v3 import preprocess_input
from keras.models import load_model
from shutil import copy
from shutil import copytree, rmtree
import tensorflow.keras.backend 
from tensorflow.keras.models import load_model
from tensorflow.keras.preprocessing import image
from tensorflow.keras import regularizers
from tensorflow.keras.applications.inception_v3 import InceptionV3
from tensorflow.keras.models import Sequential, Model
from tensorflow.keras.layers import Dense, Dropout, Activation, Flatten
from tensorflow.keras.layers import Convolution2D, MaxPooling2D, ZeroPadding2D, GlobalAveragePooling2D, AveragePooling2D
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.regularizers import l2
from tensorflow import keras
from tensorflow.keras import models

# %%
def split_path(data, mode='id'):
    if mode == 'class':
        return data.split('/')[0]
    return data.split('/')[-1]

def format_path(path):
    return f'C:/Users/kurt_/Desktop/food-101/images/{path}.jpg'

# %%
import pandas as pd

# Load dataset
train = pd.read_csv(r'C:\Users\kurt_\Desktop\food-101\meta\train.txt', header=None, names=['path'])
test = pd.read_csv(r'C:\Users\kurt_\Desktop\food-101\meta\test.txt', header=None, names=['path'])

# %%
# Process data
train['label'] = train['path'].map(lambda x: split_path(x, 'class')) 
train['idx'] = train['path'].map(split_path) 
test['label'] = test['path'].map(lambda x: split_path(x, 'class')) 
test['idx'] = test['path'].map(split_path) 

# Tüm sınıfları içeren bir listeyi oluştur
classes = train['label'].unique()

# Veri yolu formatını güncelle
train['path'] = train['path'].apply(format_path)
test['path'] = test['path'].apply(format_path)

# %%
# Düzeltilmiş fonksiyonları tanımlayalım

def copy_files(data, destination):
    # Verilen veri kümesindeki dosyaları ilgili sınıflara göre kopyalar
    for index, row in data.iterrows():
        src = row['path']
        label = row['label']
        dst = os.path.join(destination, label, row['idx'] + '.jpg')
        shutil.copy(src, dst)

# Train ve Test için klasörler oluşturalım
train_data_path = 'C:/Users/kurt_/Desktop/food-101/train'
test_data_path = 'C:/Users/kurt_/Desktop/food-101/test'

create_folders(train_data_path)
create_folders(test_data_path)

# Dosyaları kopyalayalım
copy_files(train, train_data_path)
copy_files(test, test_data_path)

# %%
def count_images_in_classes(folder_path):
    class_counts = {}
    for class_name in os.listdir(folder_path):
        class_dir = os.path.join(folder_path, class_name)
        if os.path.isdir(class_dir):
            num_images = len([file for file in os.listdir(class_dir) if file.endswith('.jpg')])
            class_counts[class_name] = num_images
    return class_counts

# Train ve test klasörlerindeki sınıf adlarını ve resim sayılarını yazdıralım
train_class_counts = count_images_in_classes(train_data_path)
test_class_counts = count_images_in_classes(test_data_path)

print("Train Klasöründeki Sınıflar ve Resim Sayıları:")
for class_name, count in train_class_counts.items():
    print(f"{class_name}: {count} resim")

print("\nTest Klasöründeki Sınıflar ve Resim Sayıları:")
for class_name, count in test_class_counts.items():
    print(f"{class_name}: {count} resim")
# Out:
# Train Klasöründeki Sınıflar ve Resim Sayıları:
# apple_pie: 750 resim
# baby_back_ribs: 750 resim
# baklava: 750 resim
# beef_carpaccio: 750 resim
# beef_tartare: 750 resim
# beet_salad: 750 resim
# beignets: 750 resim
# bibimbap: 750 resim
# bread_pudding: 750 resim
# breakfast_burrito: 750 resim
# bruschetta: 750 resim
# caesar_salad: 750 resim
# cannoli: 750 resim
# caprese_salad: 750 resim
# carrot_cake: 750 resim
# ceviche: 750 resim
# croque_madame: 250 resim
# cup_cakes: 250 resim
# deviled_eggs: 250 resim
# donuts: 250 resim
# dumplings: 250 resim
# edamame: 250 resim
# eggs_benedict: 250 resim
# escargots: 250 resim
# falafel: 250 resim
# filet_mignon: 250 resim
# fish_and_chips: 250 resim
# foie_gras: 250 resim
# french_fries: 250 resim
# french_onion_soup: 250 resim
# french_toast: 250 resim
# fried_calamari: 250 resim
# fried_rice: 250 resim
# frozen_yogurt: 250 resim
# garlic_bread: 250 resim
# gnocchi: 250 resim
# greek_salad: 250 resim
# grilled_cheese_sandwich: 250 resim
# grilled_salmon: 250 resim
# guacamole: 250 resim
# gyoza: 250 resim
# hamburger: 250 resim
# hot_and_sour_soup: 250 resim
# hot_dog: 250 resim
# huevos_rancheros: 250 resim
# hummus: 250 resim
# ice_cream: 250 resim
# lasagna: 250 resim
# lobster_bisque: 250 resim
# lobster_roll_sandwich: 250 resim
# macaroni_and_cheese: 250 resim
# macarons: 250 resim
# miso_soup: 250 resim
# mussels: 250 resim
# nachos: 250 resim
# omelette: 250 resim
# onion_rings: 250 resim
# oysters: 250 resim
# pad_thai: 250 resim
# paella: 250 resim
# pancakes: 250 resim
# panna_cotta: 250 resim
# peking_duck: 250 resim
# pho: 250 resim
# pizza: 250 resim
# pork_chop: 250 resim
# poutine: 250 resim
# prime_rib: 250 resim
# pulled_pork_sandwich: 250 resim
# ramen: 250 resim
# ravioli: 250 resim
# red_velvet_cake: 250 resim
# risotto: 250 resim
# samosa: 250 resim
# sashimi: 250 resim
# scallops: 250 resim
# seaweed_salad: 250 resim
# shrimp_and_grits: 250 resim
# spaghetti_bolognese: 250 resim
# spaghetti_carbonara: 250 resim
# spring_rolls: 250 resim
# steak: 250 resim
# strawberry_shortcake: 250 resim
# sushi: 250 resim
# tacos: 250 resim
# takoyaki: 250 resim
# tiramisu: 250 resim
# tuna_tartare: 250 resim
# waffles: 250 resim

# %%
def find_duplicate_images(train_folder, test_folder):
    duplicate_found = False

    for class_name in os.listdir(train_folder):
        train_class_dir = os.path.join(train_folder, class_name)
        test_class_dir = os.path.join(test_folder, class_name)

        if os.path.isdir(train_class_dir) and os.path.isdir(test_class_dir):
            train_images = set(os.listdir(train_class_dir))
            test_images = set(os.listdir(test_class_dir))

            common_images = train_images.intersection(test_images)
            for image_file in common_images:
                train_image_path = os.path.join(train_class_dir, image_file)
                test_image_path = os.path.join(test_class_dir, image_file)
                if compare_images(train_image_path, test_image_path):
                    duplicate_found = True
                    break

    if duplicate_found:
        print("Train ve test klasörleri arasında aynı içeriğe sahip resim dosyaları bulundu.")
    else:
        print("Train ve test klasörleri arasında aynı içeriğe sahip resim dosyası bulunamadı.")

# Train ve test klasörleri arasında yinelenen resim dosyalarını kontrol edelim
find_duplicate_images(train_data_path, test_data_path)
# Out:
# Train ve test klasörleri arasında aynı içeriğe sahip resim dosyası bulunamadı.

# %%
def get_first_image_per_class(folder_path):
    first_images = []

    # Klasördeki sınıfları sıralayalım
    classes = sorted(os.listdir(folder_path))

    # Her sınıfın ilk resmini alalım
    for class_name in classes:
        class_dir = os.path.join(folder_path, class_name)
        if os.path.isdir(class_dir):
            images = os.listdir(class_dir)
            if images:  # Eğer sınıf klasöründe resim varsa
                image_path = os.path.join(class_dir, images[0])
                first_images.append(image_path)

    return first_images

# Train klasöründeki ilk sınıfların ilk resimlerini alalım
train_first_images = get_first_image_per_class(train_data_path)

# Test klasöründeki ilk sınıfların ilk resimlerini alalım
test_first_images = get_first_image_per_class(test_data_path)

# Sonuçları ekrana yazdıralım
print("Train klasöründeki ilk sınıfların ilk resimleri:")
for idx, image_path in enumerate(train_first_images, start=1):
    print(f"{idx}. resim: {image_path}")

print("\nTest klasöründeki ilk sınıfların ilk resimleri:")
for idx, image_path in enumerate(test_first_images, start=1):
    print(f"{idx}. resim: {image_path}")
# Out:
# Train klasöründeki ilk sınıfların ilk resimleri:
# 1. resim: C:/Users/kurt_/Desktop/food-101/train\apple_pie\1005649.jpg
# 2. resim: C:/Users/kurt_/Desktop/food-101/train\baby_back_ribs\1005293.jpg
# 3. resim: C:/Users/kurt_/Desktop/food-101/train\baklava\1006121.jpg
# 4. resim: C:/Users/kurt_/Desktop/food-101/train\beef_carpaccio\1011469.jpg
# 5. resim: C:/Users/kurt_/Desktop/food-101/train\beef_tartare\1000431.jpg
# 6. resim: C:/Users/kurt_/Desktop/food-101/train\beet_salad\1003501.jpg
# 7. resim: C:/Users/kurt_/Desktop/food-101/train\beignets\1000911.jpg
# 8. resim: C:/Users/kurt_/Desktop/food-101/train\bibimbap\1002297.jpg
# 9. resim: C:/Users/kurt_/Desktop/food-101/train\bread_pudding\1004499.jpg
# 10. resim: C:/Users/kurt_/Desktop/food-101/train\breakfast_burrito\1000351.jpg
# 11. resim: C:/Users/kurt_/Desktop/food-101/train\bruschetta\1003796.jpg
# 12. resim: C:/Users/kurt_/Desktop/food-101/train\caesar_salad\1000016.jpg
# 13. resim: C:/Users/kurt_/Desktop/food-101/train\cannoli\1007970.jpg
# 14. resim: C:/Users/kurt_/Desktop/food-101/train\caprese_salad\1001946.jpg
# 15. resim: C:/Users/kurt_/Desktop/food-101/train\carrot_cake\1000447.jpg
# 16. resim: C:/Users/kurt_/Desktop/food-101/train\ceviche\1006106.jpg
# 17. resim: C:/Users/kurt_/Desktop/food-101/train\cheese_plate\100370.jpg
# 18. resim: C:/Users/kurt_/Desktop/food-101/train\cheesecake\1001446.jpg
# 19. resim: C:/Users/kurt_/Desktop/food-101/train\chicken_curry\1004867.jpg
# 20. resim: C:/Users/kurt_/Desktop/food-101/train\chicken_quesadilla\1004279.jpg
# 21. resim: C:/Users/kurt_/Desktop/food-101/train\chicken_wings\1003533.jpg
# 22. resim: C:/Users/kurt_/Desktop/food-101/train\chocolate_cake\1001084.jpg
# 23. resim: C:/Users/kurt_/Desktop/food-101/train\chocolate_mousse\1013482.jpg
# 24. resim: C:/Users/kurt_/Desktop/food-101/train\churros\1004234.jpg
# 25. resim: C:/Users/kurt_/Desktop/food-101/train\clam_chowder\1000678.jpg
# 26. resim: C:/Users/kurt_/Desktop/food-101/train\club_sandwich\1017761.jpg
os.listdir(folder_path) if os.path.isdir(os.path.join(folder_path, name))])
    return num_classes

# Train klasöründeki sınıf sayısını alalım
num_train_classes = count_classes(train_data_path)

# Test klasöründeki sınıf sayısını alalım
num_test_classes = count_classes(test_data_path)

print(f"Train klasöründeki sınıf sayısı: {num_train_classes}")
print(f"Test klasöründeki sınıf sayısı: {num_test_classes}")
# Out:
# Train klasöründeki sınıf sayısı: 101
# Test klasöründeki sınıf sayısı: 101

# %%
import os

def count_images_in_folder(folder_path):
    total_images = 0
    for root, dirs, files in os.walk(folder_path):
        total_images += len(files)
    return total_images

# Train ve test klasörlerindeki toplam resim sayısını alalım
total_train_images = count_images_in_folder(train_data)
total_test_images = count_images_in_folder(test_data)

print("Train klasöründeki toplam resim sayısı:", total_train_images)
print("Test klasöründeki toplam resim sayısı:", total_test_images)
# Out:
# Train klasöründeki toplam resim sayısı: 75750
# Test klasöründeki toplam resim sayısı: 25250

# %%
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import InceptionV3
from tensorflow.keras.layers import GlobalAveragePooling2D, Dense, Dropout
from tensorflow.keras.models import Model
from tensorflow.keras.optimizers import SGD
from tensorflow.keras.callbacks import ModelCheckpoint, CSVLogger
from tensorflow.keras import regularizers
import tensorflow.keras.backend as K
import pandas as pd
from sklearn.model_selection import ParameterGrid
import numpy as np

# Clear Keras session
K.clear_session()

# Define constants
n_classes = 101
batch_size = 16
width, height = 299, 299
train_data = r"C:\Users\kurt_\Desktop\food-101\train"
test_data = r"C:\Users\kurt_\Desktop\food-101\test"
train_samples = 75750
test_samples = 25250

# Data generators
train_data_gen = ImageDataGenerator(rescale=1. / 255, shear_range=0.2, zoom_range=0.2, horizontal_flip=True, fill_mode='nearest', rotation_range=40, width_shift_range=0.2, height_shift_range=0.2, brightness_range=[0.6, 1.4])
test_data_gen = ImageDataGenerator(rescale=1. / 255)
train_gen = train_data_gen.flow_from_directory(train_data, target_size=(height, width), batch_size=batch_size, class_mode='categorical')
test_gen = test_data_gen.flow_from_directory(test_data, target_size=(height, width), batch_size=batch_size, class_mode='categorical')

# Function to create model
def create_model(learning_rate=0.0001, momentum=0.9, decay=1e-6, dropout_rate=0.2, l2_reg=0.005):
    # Base InceptionV3 model
    inception = InceptionV3(weights='imagenet', include_top=False)
    layer = inception.output
    layer = GlobalAveragePooling2D()(layer)
    layer = Dense(128, activation='relu')(layer)
    layer = Dropout(dropout_rate)(layer)
    predictions = Dense(n_classes, kernel_regularizer=regularizers.l2(l2_reg), activation='softmax')(layer)
    model = Model(inputs=inception.input, outputs=predictions)

    # Compile model
    optimizer = SGD(learning_rate=learning_rate, momentum=momentum, decay=decay)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])
    return model

# Define the grid search parameters
param_grid = {
    'learning_rate': [0.001, 0.0001, 0.00001],
    'momentum': [0.9, 0.95],
    'dropout_rate': [0.2, 0.3],
    'l2_reg': [0.001, 0.005, 0.01]
}

# Define a custom scoring function
def custom_scoring_function(y_true, y_pred):
    return np.mean(y_true.argmax(axis=1) == y_pred.argmax(axis=1))

# Define a DataFrame to store epoch-wise metrics
epoch_metrics = pd.DataFrame(columns=['Model Params', 'Epoch', 'Loss', 'Accuracy', 'Val Loss', 'Val Accuracy'])

# Define variables to store best model and history
best_model = None
best_history = None
best_accuracy = 0.0

# Iterate over all parameter combinations
for params in ParameterGrid(param_grid):
    print("Training model with parameters:", params)
    
    # Create model
    model = create_model(**params)
    
    # Define callbacks
    checkpoint_path = f"best_model_{n_classes}class_inceptionv3den8.hdf5"
    checkpoint = ModelCheckpoint(checkpoint_path, monitor='val_accuracy', verbose=1, save_best_only=True, mode='max')
    csv_logger = CSVLogger('history_101class_inceptionv3den8.log', append=True)
    
    # Train model
    history = model.fit(train_gen,
                        steps_per_epoch=train_samples // batch_size,
                        validation_data=test_gen,
                        validation_steps=test_samples // batch_size,
                        epochs=30,
                        callbacks=[checkpoint, csv_logger],
                        verbose=1)
    
    # Extract metrics from history
    metrics = pd.DataFrame({
        'Epoch': np.arange(1, 31),
        'Loss': history.history['loss'],
        'Accuracy': history.history['accuracy'],
        'Val Loss': history.history['val_loss'],
        'Val Accuracy': history.history['val_accuracy']
    })
    
    # Append to epoch_metrics DataFrame
    epoch_metrics = epoch_metrics.append(metrics, ignore_index=True)
    
    # Check if this model has the best accuracy so far
    if max(history.history['val_accuracy']) > best_accuracy:
        best_accuracy = max(history.history['val_accuracy'])
        best_model = model
        best_history = history

# Write epoch-wise metrics to CSV file
epoch_metrics.to_csv('epoch_metrics.csv', index=False)
# Out:
# Found 75750 images belonging to 101 classes.
# Found 25250 images belonging to 101 classes.
# Training model with parameters: {'dropout_rate': 0.2, 'l2_reg': 0.001, 'learning_rate': 0.001, 'momentum': 0.9}
# Epoch 1/30
# 4734/4734 [==============================] - ETA: 0s - loss: 2.6617 - accuracy: 0.4033
# Epoch 1: val_accuracy improved from -inf to 0.67855, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1615s 340ms/step - loss: 2.6617 - accuracy: 0.4033 - val_loss: 1.3345 - val_accuracy: 0.6785
# Epoch 2/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.6497 - accuracy: 0.6140
# Epoch 2: val_accuracy improved from 0.67855 to 0.74453, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1191s 252ms/step - loss: 1.6497 - accuracy: 0.6140 - val_loss: 1.0496 - val_accuracy: 0.7445
# Epoch 3/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.3930 - accuracy: 0.6724
# Epoch 3: val_accuracy improved from 0.74453 to 0.77182, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1695s 358ms/step - loss: 1.3930 - accuracy: 0.6724 - val_loss: 0.9619 - val_accuracy: 0.7718
# Epoch 4/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.2436 - accuracy: 0.7081
# Epoch 4: val_accuracy improved from 0.77182 to 0.77582, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1391s 294ms/step - loss: 1.2436 - accuracy: 0.7081 - val_loss: 0.9274 - val_accuracy: 0.7758
# Epoch 5/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.1274 - accuracy: 0.7343
# Epoch 5: val_accuracy improved from 0.77582 to 0.79151, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1234s 261ms/step - loss: 1.1274 - accuracy: 0.7343 - val_loss: 0.8767 - val_accuracy: 0.7915
# Epoch 6/30
# 4734/4734 [==============================] - ETA: 0s - loss: 1.0379 - accuracy: 0.7553
# Epoch 6: val_accuracy improved from 0.79151 to 0.80989, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1215s 257ms/step - loss: 1.0379 - accuracy: 0.7553 - val_loss: 0.8027 - val_accuracy: 0.8099
# Epoch 7/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.9687 - accuracy: 0.7687
# Epoch 7: val_accuracy improved from 0.80989 to 0.81111, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1180s 249ms/step - loss: 0.9687 - accuracy: 0.7687 - val_loss: 0.7846 - val_accuracy: 0.8111
# Epoch 8/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.9023 - accuracy: 0.7843
# Epoch 8: val_accuracy did not improve from 0.81111
# 4734/4734 [==============================] - 1180s 249ms/step - loss: 0.9023 - accuracy: 0.7843 - val_loss: 0.8074 - val_accuracy: 0.8061
# Epoch 9/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.8492 - accuracy: 0.7969
# Epoch 9: val_accuracy improved from 0.81111 to 0.82102, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1175s 248ms/step - loss: 0.8492 - accuracy: 0.7969 - val_loss: 0.7563 - val_accuracy: 0.8210
# Epoch 10/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.7979 - accuracy: 0.8096
# Epoch 10: val_accuracy did not improve from 0.82102
# 4734/4734 [==============================] - 1157s 244ms/step - loss: 0.7979 - accuracy: 0.8096 - val_loss: 0.8108 - val_accuracy: 0.8089
# Epoch 11/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.7517 - accuracy: 0.8198
# Epoch 11: val_accuracy improved from 0.82102 to 0.83096, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1172s 248ms/step - loss: 0.7517 - accuracy: 0.8198 - val_loss: 0.7223 - val_accuracy: 0.8310
# Epoch 12/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.7196 - accuracy: 0.8278
# Epoch 12: val_accuracy did not improve from 0.83096
# 4734/4734 [==============================] - 1181s 249ms/step - loss: 0.7196 - accuracy: 0.8278 - val_loss: 0.7493 - val_accuracy: 0.8253
# Epoch 13/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.6782 - accuracy: 0.8375
# Epoch 13: val_accuracy improved from 0.83096 to 0.83195, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1158s 245ms/step - loss: 0.6782 - accuracy: 0.8375 - val_loss: 0.7153 - val_accuracy: 0.8319
# Epoch 14/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.6439 - accuracy: 0.8441
# Epoch 14: val_accuracy did not improve from 0.83195
# 4734/4734 [==============================] - 1171s 247ms/step - loss: 0.6439 - accuracy: 0.8441 - val_loss: 0.7880 - val_accuracy: 0.8205
# Epoch 15/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.6145 - accuracy: 0.8519
# Epoch 15: val_accuracy did not improve from 0.83195
# 4734/4734 [==============================] - 1176s 248ms/step - loss: 0.6145 - accuracy: 0.8519 - val_loss: 0.7404 - val_accuracy: 0.8300
# Epoch 16/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.5839 - accuracy: 0.8576
# Epoch 16: val_accuracy improved from 0.83195 to 0.83480, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1159s 245ms/step - loss: 0.5839 - accuracy: 0.8576 - val_loss: 0.7252 - val_accuracy: 0.8348
# Epoch 17/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.5585 - accuracy: 0.8653
# Epoch 17: val_accuracy improved from 0.83480 to 0.84700, saving model to best_model_101class_inceptionv3den8.hdf5
# 4734/4734 [==============================] - 1172s 248ms/step - loss: 0.5585 - accuracy: 0.8653 - val_loss: 0.6742 - val_accuracy: 0.8470
# Epoch 18/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.5255 - accuracy: 0.8737
# Epoch 18: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1179s 249ms/step - loss: 0.5255 - accuracy: 0.8737 - val_loss: 0.8119 - val_accuracy: 0.8161
# Epoch 19/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.5107 - accuracy: 0.8764
# Epoch 19: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1160s 245ms/step - loss: 0.5107 - accuracy: 0.8764 - val_loss: 0.7495 - val_accuracy: 0.8321
# Epoch 20/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.4802 - accuracy: 0.8851
# Epoch 20: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1169s 247ms/step - loss: 0.4802 - accuracy: 0.8851 - val_loss: 0.7257 - val_accuracy: 0.8405
# Epoch 21/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.4621 - accuracy: 0.8889
# Epoch 21: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1228s 259ms/step - loss: 0.4621 - accuracy: 0.8889 - val_loss: 0.8008 - val_accuracy: 0.8251
# Epoch 22/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.4380 - accuracy: 0.8959
# Epoch 22: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1176s 248ms/step - loss: 0.4380 - accuracy: 0.8959 - val_loss: 0.8075 - val_accuracy: 0.8249
# Epoch 23/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.4213 - accuracy: 0.8998
# Epoch 23: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1178s 249ms/step - loss: 0.4213 - accuracy: 0.8998 - val_loss: 0.7298 - val_accuracy: 0.8426
# Epoch 24/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.4013 - accuracy: 0.9039
# Epoch 24: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1178s 249ms/step - loss: 0.4013 - accuracy: 0.9039 - val_loss: 0.7254 - val_accuracy: 0.8390
# Epoch 25/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.3857 - accuracy: 0.9089
# Epoch 25: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1166s 246ms/step - loss: 0.3857 - accuracy: 0.9089 - val_loss: 0.7691 - val_accuracy: 0.8357
# Epoch 26/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.3726 - accuracy: 0.9131
# Epoch 26: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1170s 247ms/step - loss: 0.3726 - accuracy: 0.9131 - val_loss: 0.7315 - val_accuracy: 0.8420
# Epoch 27/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.3504 - accuracy: 0.9181
# Epoch 27: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1173s 248ms/step - loss: 0.3504 - accuracy: 0.9181 - val_loss: 0.8309 - val_accuracy: 0.8228
# Epoch 28/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.3364 - accuracy: 0.9215
# Epoch 28: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1161s 245ms/step - loss: 0.3364 - accuracy: 0.9215 - val_loss: 0.7187 - val_accuracy: 0.8457
# Epoch 29/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.3218 - accuracy: 0.9253
# Epoch 29: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1161s 245ms/step - loss: 0.3218 - accuracy: 0.9253 - val_loss: 0.7833 - val_accuracy: 0.8332
# Epoch 30/30
# 4734/4734 [==============================] - ETA: 0s - loss: 0.3122 - accuracy: 0.9288
# Epoch 30: val_accuracy did not improve from 0.84700
# 4734/4734 [==============================] - 1170s 247ms/step - loss: 0.3122 - accuracy: 0.9288 - val_loss: 0.7810 - val_accuracy: 0.8384
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19092\2712023397.py in ?()
#      94         'Val Accuracy': history.history['val_accuracy']
#      95     })
#      96
#      97     # Append to epoch_metrics DataFrame
# ---> 98     epoch_metrics = epoch_metrics.append(metrics, ignore_index=True)
#      99
#     100     # Check if this model has the best accuracy so far
#     101     if max(history.history['val_accuracy']) > best_accuracy:
#
# ~\anaconda3\envs\tensorflowgpuden\lib\site-packages\pandas\core\generic.py in ?(self, name)
#    6292             and name not in self._accessors
#    6293             and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    6294         ):
#    6295             return self[name]
# -> 6296         return object.__getattribute__(self, name)
#
# AttributeError: 'DataFrame' object has no attribute 'append'

# %%
model_path = r"C:\Users\kurt_\best_model_101class_inceptionv3den8.hdf5"
test_data_path = r"C:\Users\kurt_\Desktop\food-101\test"

# %%
# Performans metriklerini hesaplamak için fonksiyon tanımla
def calculate_metrics(model, test_gen):
    # Modelden tahminler yap
    predictions = model.predict(test_gen)
    predicted_classes = np.argmax(predictions, axis=1)
    
    # Gerçek sınıfları al
    true_classes = test_gen.classes
    
    # Sınıf etiketlerini al
    class_labels = list(test_gen.class_indices.keys())

    # Doğruluk, hassasiyet, geri çağırma ve F1 puanını hesapla
    accuracy = accuracy_score(true_classes, predicted_classes)
    precision = precision_score(true_classes, predicted_classes, average='weighted')
    recall = recall_score(true_classes, predicted_classes, average='weighted')
    f1 = f1_score(true_classes, predicted_classes, average='weighted')

    return accuracy, precision, recall, f1

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
# Boyutları tanımla
height, width = 299, 299

# Batch boyutunu tanımla
batch_size = 16

# Test veri üreteci oluştur
test_data_gen = ImageDataGenerator(rescale=1. / 255)
test_gen = test_data_gen.flow_from_directory(test_data_path, target_size=(height, width), batch_size=batch_size, class_mode='categorical', shuffle=False)

# Modeli yükle
model = load_model(model_path, compile=False)

# Performans metriklerini hesapla
accuracy, precision, recall, f1_score = calculate_metrics(model, test_gen)

# Hesaplanan metrikleri yazdır
print("Accuracy:", accuracy)
print("Precision:", precision)
print("Recall:", recall)
print("F1 Score:", f1_score)
# Out:
# Found 25250 images belonging to 101 classes.
# 1579/1579 [==============================] - 76s 48ms/step
# Accuracy: 0.847009900990099
# Precision: 0.8513280760276849
# Recall: 0.847009900990099
# F1 Score: 0.8468793258456037

# %%
import os
import numpy as np
from keras.models import load_model
from keras.preprocessing.image import ImageDataGenerator

# Model ve test veri yolu
model_path = r"C:\Users\kurt_\best_model_101class_inceptionv3den8.hdf5"
test_data_path = r"C:\Users\kurt_\Desktop\food-101\test"

# Modeli yükle
model = load_model(model_path)

# Sınıf etiketlerini yükle
class_labels = sorted(os.listdir(test_data_path))

# Veri yükleyici oluştur
datagen = ImageDataGenerator(rescale=1./255)
test_generator = datagen.flow_from_directory(
    test_data_path,
    target_size=(299, 299),
    batch_size=32,
    class_mode=None,  # Sınıf etiketlerini almak yerine, sadece resimleri döndürür
    shuffle=False
)

# Test verisi üzerinde tahminler yap
predictions = model.predict(test_generator, steps=len(test_generator), verbose=1)

# En az ve en çok tahmin edilen sınıfları ve yüzdelerini bul
min_confidence = 1.0
max_confidence = 0.0
min_class = ""
max_class = ""

for i in range(len(predictions)):
    prediction = predictions[i]
    true_class_index = np.argmax(prediction)
    confidence = np.max(prediction)
    true_class_label = class_labels[true_class_index]

    if confidence < min_confidence:
        min_confidence = confidence
        min_class = true_class_label
    if confidence > max_confidence:
        max_confidence = confidence
        max_class = true_class_label

# En az ve en çok tahmin edilen sınıfları ve yüzdelerini yazdır
print("En az tahmin edilen sınıf: {} %{}".format(min_class, round(min_confidence * 100, 2)))
print("En çok tahmin edilen sınıf: {} %{}".format(max_class, round(max_confidence * 100, 2)))
# Out:
# Found 25250 images belonging to 101 classes.
# 790/790 [==============================] - 75s 95ms/step
# En az tahmin edilen sınıf: hummus %9.27
# En çok tahmin edilen sınıf: apple_pie %100.0

# %%
import os
import numpy as np
from keras.models import load_model
from PIL import Image
from random import sample

# Model ve test veri yolu
model_path = r"C:\Users\kurt_\best_model_101class_inceptionv3den8.hdf5"
test_data_path = r"C:\Users\kurt_\Desktop\food-101\test"

# Modeli yükle
model = load_model(model_path)

# Sınıf etiketlerini yükle
class_labels = sorted(os.listdir(test_data_path))

# Rastgele 10 resim seç
random_classes = sample(class_labels, 10)
for class_label in random_classes:
    class_path = os.path.join(test_data_path, class_label)
    images = os.listdir(class_path)
    img_name = np.random.choice(images)
    img_path = os.path.join(class_path, img_name)
    img = Image.open(img_path)
    img = img.resize((299, 299))  # Modelin beklendiği boyuta uygun olarak yeniden boyutlandır
    img_array = np.array(img)  # PIL Image'i numpy dizisine dönüştür
    img_array = np.expand_dims(img_array, axis=0)  # Tek bir örnek için boyut ekleyin
    img_array = img_array.astype('float32') / 255  # Normalleştirme
    prediction = model.predict(img_array)
    class_index = np.argmax(prediction)
    confidence = prediction[0][class_index]
    predicted_class = class_labels[class_index]
    print("Gerçek Sınıf: {}, Tahmin Edilen Sınıf: {} (Tahmin Yüzdesi: {}%)".format(class_label, predicted_class, round(confidence * 100, 2)))
# Out:
# 1/1 [==============================] - 1s 627ms/step
# Gerçek Sınıf: chocolate_mousse, Tahmin Edilen Sınıf: chocolate_mousse (Tahmin Yüzdesi: 98.62%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: miso_soup, Tahmin Edilen Sınıf: miso_soup (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: french_onion_soup, Tahmin Edilen Sınıf: french_onion_soup (Tahmin Yüzdesi: 99.96%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: apple_pie, Tahmin Edilen Sınıf: apple_pie (Tahmin Yüzdesi: 99.24%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: grilled_cheese_sandwich, Tahmin Edilen Sınıf: grilled_cheese_sandwich (Tahmin Yüzdesi: 74.93%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: gyoza, Tahmin Edilen Sınıf: gyoza (Tahmin Yüzdesi: 99.81%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: greek_salad, Tahmin Edilen Sınıf: greek_salad (Tahmin Yüzdesi: 49.34%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: seaweed_salad, Tahmin Edilen Sınıf: seaweed_salad (Tahmin Yüzdesi: 83.51%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: chicken_quesadilla, Tahmin Edilen Sınıf: chicken_quesadilla (Tahmin Yüzdesi: 99.9%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: croque_madame, Tahmin Edilen Sınıf: croque_madame (Tahmin Yüzdesi: 99.64%)

# %%
import os
import numpy as np
from keras.models import load_model
from PIL import Image

# Model ve test veri yolu
model_path = r"C:\Users\kurt_\best_model_101class_inceptionv3den8.hdf5"
test_data_path = r"C:\Users\kurt_\Desktop\food-101\test"

# Modeli yükle
model = load_model(model_path)

# Sınıf etiketlerini yükle
class_labels = sorted(os.listdir(test_data_path))

# Eşik değeri
threshold = 0.7  # Örnek bir eşik değeri, isteğe bağlı olarak değiştirilebilir

# Her bir sınıftan birer resim seç ve tahmin et
not_confident_predictions = 0  # Güvenilir tahmin yapılamayan sınıfları saymak için sayaç

for class_label in class_labels:
    class_path = os.path.join(test_data_path, class_label)
    images = os.listdir(class_path)
    img_name = np.random.choice(images)
    img_path = os.path.join(class_path, img_name)
    img = Image.open(img_path)
    img = img.resize((299, 299))  # Modelin beklendiği boyuta uygun olarak yeniden boyutlandır
    img_array = np.array(img)  # PIL Image'i numpy dizisine dönüştür
    img_array = np.expand_dims(img_array, axis=0)  # Tek bir örnek için boyut ekleyin
    img_array = img_array.astype('float32') / 255  # Normalleştirme
    prediction = model.predict(img_array)
    class_index = np.argmax(prediction)
    confidence = prediction[0][class_index]
    predicted_class = class_labels[class_index]
    
    # Tahmin güvenilirliğini değerlendir
    if confidence >= threshold:
        print("Gerçek Sınıf: {}, Tahmin Edilen Sınıf: {} (Tahmin Yüzdesi: {}%)".format(class_label, predicted_class, round(confidence * 100, 2)))
    else:
        print("Gerçek Sınıf: {}, Model güvenilir bir tahminde bulunamadı.".format(class_label))
        not_confident_predictions += 1

print("Toplam {} resmin güvenilir bir tahminde bulunamadığı durumlar bulunmaktadır.".format(not_confident_predictions))
# Out:
# 1/1 [==============================] - 1s 610ms/step
# Gerçek Sınıf: apple_pie, Tahmin Edilen Sınıf: apple_pie (Tahmin Yüzdesi: 96.48%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: baby_back_ribs, Tahmin Edilen Sınıf: baby_back_ribs (Tahmin Yüzdesi: 99.86%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: baklava, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: beef_carpaccio, Tahmin Edilen Sınıf: beef_tartare (Tahmin Yüzdesi: 74.71%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: beef_tartare, Tahmin Edilen Sınıf: beef_tartare (Tahmin Yüzdesi: 99.88%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: beet_salad, Tahmin Edilen Sınıf: beet_salad (Tahmin Yüzdesi: 99.69%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: beignets, Tahmin Edilen Sınıf: beignets (Tahmin Yüzdesi: 99.87%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: bibimbap, Tahmin Edilen Sınıf: bibimbap (Tahmin Yüzdesi: 99.66%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: bread_pudding, Tahmin Edilen Sınıf: bread_pudding (Tahmin Yüzdesi: 98.62%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: breakfast_burrito, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: bruschetta, Tahmin Edilen Sınıf: bruschetta (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: caesar_salad, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: cannoli, Tahmin Edilen Sınıf: cannoli (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: caprese_salad, Tahmin Edilen Sınıf: caprese_salad (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: carrot_cake, Tahmin Edilen Sınıf: carrot_cake (Tahmin Yüzdesi: 99.58%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: ceviche, Tahmin Edilen Sınıf: ceviche (Tahmin Yüzdesi: 88.56%)
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: cheese_plate, Tahmin Edilen Sınıf: cheese_plate (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: cheesecake, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: chicken_curry, Tahmin Edilen Sınıf: chicken_curry (Tahmin Yüzdesi: 79.96%)
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: chicken_quesadilla, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: chicken_wings, Tahmin Edilen Sınıf: chicken_wings (Tahmin Yüzdesi: 83.13%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: chocolate_cake, Tahmin Edilen Sınıf: chocolate_cake (Tahmin Yüzdesi: 99.76%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: chocolate_mousse, Tahmin Edilen Sınıf: chocolate_mousse (Tahmin Yüzdesi: 73.8%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: churros, Tahmin Edilen Sınıf: churros (Tahmin Yüzdesi: 98.12%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: clam_chowder, Tahmin Edilen Sınıf: clam_chowder (Tahmin Yüzdesi: 94.61%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: club_sandwich, Tahmin Edilen Sınıf: club_sandwich (Tahmin Yüzdesi: 99.85%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: crab_cakes, Tahmin Edilen Sınıf: crab_cakes (Tahmin Yüzdesi: 99.93%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: creme_brulee, Tahmin Edilen Sınıf: creme_brulee (Tahmin Yüzdesi: 90.18%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: croque_madame, Tahmin Edilen Sınıf: croque_madame (Tahmin Yüzdesi: 99.93%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: cup_cakes, Tahmin Edilen Sınıf: cup_cakes (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: deviled_eggs, Tahmin Edilen Sınıf: deviled_eggs (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: donuts, Tahmin Edilen Sınıf: donuts (Tahmin Yüzdesi: 99.91%)
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: dumplings, Tahmin Edilen Sınıf: dumplings (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: edamame, Tahmin Edilen Sınıf: edamame (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: eggs_benedict, Tahmin Edilen Sınıf: eggs_benedict (Tahmin Yüzdesi: 71.76%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: escargots, Tahmin Edilen Sınıf: escargots (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: falafel, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: filet_mignon, Tahmin Edilen Sınıf: filet_mignon (Tahmin Yüzdesi: 94.16%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: fish_and_chips, Tahmin Edilen Sınıf: fish_and_chips (Tahmin Yüzdesi: 98.38%)
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: foie_gras, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: french_fries, Tahmin Edilen Sınıf: french_fries (Tahmin Yüzdesi: 99.97%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: french_onion_soup, Tahmin Edilen Sınıf: french_onion_soup (Tahmin Yüzdesi: 99.72%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: french_toast, Tahmin Edilen Sınıf: french_toast (Tahmin Yüzdesi: 97.45%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: fried_calamari, Tahmin Edilen Sınıf: fried_calamari (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: fried_rice, Tahmin Edilen Sınıf: fried_rice (Tahmin Yüzdesi: 99.9%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: frozen_yogurt, Tahmin Edilen Sınıf: frozen_yogurt (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: garlic_bread, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: gnocchi, Tahmin Edilen Sınıf: gnocchi (Tahmin Yüzdesi: 95.25%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: greek_salad, Tahmin Edilen Sınıf: greek_salad (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: grilled_cheese_sandwich, Tahmin Edilen Sınıf: grilled_cheese_sandwich (Tahmin Yüzdesi: 99.53%)
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: grilled_salmon, Tahmin Edilen Sınıf: grilled_salmon (Tahmin Yüzdesi: 93.06%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: guacamole, Tahmin Edilen Sınıf: guacamole (Tahmin Yüzdesi: 99.96%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: gyoza, Tahmin Edilen Sınıf: gyoza (Tahmin Yüzdesi: 99.84%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: hamburger, Tahmin Edilen Sınıf: hamburger (Tahmin Yüzdesi: 99.87%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: hot_and_sour_soup, Tahmin Edilen Sınıf: hot_and_sour_soup (Tahmin Yüzdesi: 94.4%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: hot_dog, Tahmin Edilen Sınıf: hot_dog (Tahmin Yüzdesi: 88.51%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: huevos_rancheros, Tahmin Edilen Sınıf: huevos_rancheros (Tahmin Yüzdesi: 95.12%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: hummus, Tahmin Edilen Sınıf: hummus (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: ice_cream, Tahmin Edilen Sınıf: ice_cream (Tahmin Yüzdesi: 99.33%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: lasagna, Tahmin Edilen Sınıf: lasagna (Tahmin Yüzdesi: 99.55%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: lobster_bisque, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: lobster_roll_sandwich, Tahmin Edilen Sınıf: lobster_roll_sandwich (Tahmin Yüzdesi: 99.89%)
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: macaroni_and_cheese, Tahmin Edilen Sınıf: macaroni_and_cheese (Tahmin Yüzdesi: 99.98%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: macarons, Tahmin Edilen Sınıf: macarons (Tahmin Yüzdesi: 99.83%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: miso_soup, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: mussels, Tahmin Edilen Sınıf: mussels (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: nachos, Tahmin Edilen Sınıf: nachos (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: omelette, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 22ms/step
# Gerçek Sınıf: onion_rings, Tahmin Edilen Sınıf: onion_rings (Tahmin Yüzdesi: 96.15%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: oysters, Tahmin Edilen Sınıf: oysters (Tahmin Yüzdesi: 99.94%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: pad_thai, Tahmin Edilen Sınıf: pad_thai (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: paella, Tahmin Edilen Sınıf: paella (Tahmin Yüzdesi: 99.96%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: pancakes, Tahmin Edilen Sınıf: pancakes (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: panna_cotta, Tahmin Edilen Sınıf: panna_cotta (Tahmin Yüzdesi: 99.97%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: peking_duck, Tahmin Edilen Sınıf: peking_duck (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: pho, Tahmin Edilen Sınıf: pho (Tahmin Yüzdesi: 96.23%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: pizza, Tahmin Edilen Sınıf: pizza (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: pork_chop, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: poutine, Tahmin Edilen Sınıf: poutine (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: prime_rib, Tahmin Edilen Sınıf: prime_rib (Tahmin Yüzdesi: 99.97%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: pulled_pork_sandwich, Tahmin Edilen Sınıf: pulled_pork_sandwich (Tahmin Yüzdesi: 99.65%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: ramen, Tahmin Edilen Sınıf: ramen (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: ravioli, Tahmin Edilen Sınıf: chicken_curry (Tahmin Yüzdesi: 78.12%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: red_velvet_cake, Tahmin Edilen Sınıf: red_velvet_cake (Tahmin Yüzdesi: 99.84%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: risotto, Tahmin Edilen Sınıf: risotto (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: samosa, Tahmin Edilen Sınıf: samosa (Tahmin Yüzdesi: 87.34%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: sashimi, Tahmin Edilen Sınıf: sashimi (Tahmin Yüzdesi: 99.35%)
# 1/1 [==============================] - 0s 18ms/step
# Gerçek Sınıf: scallops, Tahmin Edilen Sınıf: scallops (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: seaweed_salad, Tahmin Edilen Sınıf: seaweed_salad (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: shrimp_and_grits, Tahmin Edilen Sınıf: shrimp_and_grits (Tahmin Yüzdesi: 99.99%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: spaghetti_bolognese, Tahmin Edilen Sınıf: spaghetti_bolognese (Tahmin Yüzdesi: 99.97%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: spaghetti_carbonara, Tahmin Edilen Sınıf: spaghetti_carbonara (Tahmin Yüzdesi: 99.87%)
# 1/1 [==============================] - 0s 19ms/step
# Gerçek Sınıf: spring_rolls, Tahmin Edilen Sınıf: spring_rolls (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: steak, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: strawberry_shortcake, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: sushi, Tahmin Edilen Sınıf: sushi (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: tacos, Tahmin Edilen Sınıf: tacos (Tahmin Yüzdesi: 98.2%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: takoyaki, Tahmin Edilen Sınıf: takoyaki (Tahmin Yüzdesi: 100.0%)
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: tiramisu, Tahmin Edilen Sınıf: tiramisu (Tahmin Yüzdesi: 99.96%)
# 1/1 [==============================] - 0s 21ms/step
# Gerçek Sınıf: tuna_tartare, Model güvenilir bir tahminde bulunamadı.
# 1/1 [==============================] - 0s 20ms/step
# Gerçek Sınıf: waffles, Tahmin Edilen Sınıf: waffles (Tahmin Yüzdesi: 99.49%)
# Toplam 15 resmin güvenilir bir tahminde bulunamadığı durumlar bulunmaktadır.
